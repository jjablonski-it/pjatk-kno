# %%
import snscrape.modules.twitter as sntwitter
import pandas as pd

# %%
tweet_topic = 'metaverse'
tweet_count = 100

# %%
# Get tweets
tweets = []
for i, tweet in enumerate(sntwitter.TwitterSearchScraper(f'{tweet_topic} near:Gdansk within:10km').get_items()):
    if i >= tweet_count:
        break
    tweets.append(tweet)
len(tweets)
# Out:
# 13

# %%
tweets_df = pd.DataFrame(tweets, columns=['date', 'id', 'content', 'user', 'sourceLabel', 'lang', 'likeCount'])
tweets_df
# Out:
#                         date                   id  \
# 0  2022-10-15 12:00:00+00:00  1581253554068652040
# 1  2022-10-14 13:54:38+00:00  1580920017541267457
# 2  2022-10-11 13:05:57+00:00  1579820602453807105
# 3  2022-10-11 08:03:55+00:00  1579744591435419648
# 4  2022-10-10 15:19:55+00:00  1579491925102833665
# 5  2022-10-10 15:18:02+00:00  1579491454699057152
# 6  2022-10-10 15:00:13+00:00  1579486969067089922
# 7  2022-10-10 15:00:12+00:00  1579486964881174531
# 8  2022-10-07 21:26:11+00:00  1578496938348990464
# 9  2022-10-07 12:01:11+00:00  1578354750298664960
# 10 2022-08-29 09:45:24+00:00  1564187453627535361
# 11 2022-05-17 10:00:07+00:00  1526502818823262208
# 12 2022-01-17 10:16:33+00:00  1483020408261652483
#
#                                               content  \
# 0   We have finished the #MetaverseWeek!🥳\n\nWe ha...
# 1   Myślę, że metaverse jednak zostanie przepchany...
# 2   New #contest!\nWe are celebrating #MetaverseWe...
# ...
